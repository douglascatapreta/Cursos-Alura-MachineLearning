# %%
import pandas as pd

uri = "https://gist.githubusercontent.com/guilhermesilveira/e99a526b2e7ccc6c3b70f53db43a87d2/raw/1605fc74aa778066bf2e6695e24d53cf65f2f447/machine-learning-carros-simulacao.csv"
dados = pd.read_csv(uri).drop(columns=["Unnamed: 0"], axis=1)
dados.head()
# Out:
#        preco  vendido  idade_do_modelo   km_por_ano
# 0   30941.02        1               18  35085.22134
# 1   40557.96        1               20  12622.05362
# 2   89627.50        0               12  11440.79806
# 3   95276.14        0                3  43167.32682
# 4  117384.68        1                4  12770.11290

# %%
# situação horrível de "azar" onde as classes estão ordenadas por padrão

dados_azar = dados.sort_values("vendido", ascending=True)
x_azar = dados_azar[["preco", "idade_do_modelo", "km_por_ano"]]
y_azar = dados_azar["vendido"]
dados_azar.head()
# Out:
#          preco  vendido  idade_do_modelo   km_por_ano
# 4999  74023.29        0               12  24812.80412
# 5322  84843.49        0               13  23095.63834
# 5319  83100.27        0               19  36240.72746
# 5316  87932.13        0               16  32249.56426
# 5315  77937.01        0               15  28414.50704

# %%
from sklearn.model_selection import cross_validate
from sklearn.dummy import DummyClassifier
import numpy as np

SEED = 301
np.random.seed(SEED)

modelo = DummyClassifier()
results = cross_validate(modelo, x_azar, y_azar, cv=10, return_train_score=False)
media = results["test_score"].mean()
desvio_padrao = results["test_score"].std()
print("Accuracy com dummy stratified, 10 = [%.2f, %.2f]" % ((media - 2 * desvio_padrao) * 100, (media + 2 * desvio_padrao) * 100))
# Out:
# Accuracy com dummy stratified, 10 = [49.79, 53.45]
# /usr/local/lib/python3.6/dist-packages/sklearn/dummy.py:132: FutureWarning: The default value of strategy will change from stratified to prior in 0.24.
#   "stratified to prior in 0.24.", FutureWarning)

# %%
from sklearn.tree import DecisionTreeClassifier

modelo = DecisionTreeClassifier(max_depth=2)
results = cross_validate(modelo, x_azar, y_azar, cv=10, return_train_score=False)
media = results["test_score"].mean()
desvio_padrao = results["test_score"].std()
print("Accuracy com cross validation, 10 = [%.2f, %.2f]" % ((media - 2 * desvio_padrao) * 100, (media + 2 * desvio_padrao) * 100))
# Out:
# Accuracy com cross validation, 10 = [73.83, 77.73]

# %%
# gerando dados aleatórios de modelo de carro para simulação de agrupamento ao usar nosso estimador

dados["modelo"] = dados.idade_do_modelo + np.random.randint(-2, 3, size=10000)
dados.modelo = dados.modelo + abs(dados.modelo.min()) + 1
dados.head()
# Out:
#        preco  vendido  idade_do_modelo   km_por_ano  modelo
# 0   30941.02        1               18  35085.22134      20
# 1   40557.96        1               20  12622.05362      23
# 2   89627.50        0               12  11440.79806      16
# 3   95276.14        0                3  43167.32682       6
# 4  117384.68        1                4  12770.11290       8

# %%
def imprime_resultados(results):
  media = results["test_score"].mean() * 100
  desvio = results["test_score"].std() * 100
  print("Accuracy médio %.2f" % media)
  print("Intervalo [%.2f, %.2f]" % (media - 2 * desvio, media + 2 * desvio))

# %%
# GroupKFold em um pipeline com StandardScaler e SVC

from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GroupKFold

scaler = StandardScaler()
modelo = SVC()

pipeline = Pipeline([("transformacao", scaler), ("estimador", modelo)])

cv = GroupKFold(n_splits=10)
results = cross_validate(pipeline, x_azar, y_azar, cv=cv, groups=dados.modelo, return_train_score=False)
imprime_resultados(results)
# Out:
# Accuracy médio 76.53
# Intervalo [73.70, 79.37]

# %%
# GroupKFold para analisar como o modelo se comporta com novos grupos

cv = GroupKFold(n_splits=10)
modelo = DecisionTreeClassifier(max_depth=2)
results = cross_validate(modelo, x_azar, y_azar, cv=cv, groups=dados.modelo, return_train_score=False)
imprime_resultados(results)
# Out:
# Accuracy médio 75.78
# Intervalo [73.38, 78.18]

# %%
from sklearn.tree import export_graphviz
import graphviz

modelo.fit(x_azar, y_azar)
features = x_azar.columns
dot_data = export_graphviz(modelo, out_file=None, filled=True, rounded=True, class_names=["não", "sim"], feature_names=features)
graph = graphviz.Source(dot_data)
graph

# %%
cv = GroupKFold(n_splits=10)
modelo = DecisionTreeClassifier(max_depth=3)
results = cross_validate(modelo, x_azar, y_azar, cv=cv, groups=dados.modelo, return_train_score=False)
imprime_resultados(results)
# Out:
# Accuracy médio 78.67
# Intervalo [75.32, 82.03]

# %%
modelo.fit(x_azar, y_azar)
features = x_azar.columns
dot_data = export_graphviz(modelo, out_file=None, filled=True, rounded=True, class_names=["não", "sim"], feature_names=features)
graph = graphviz.Source(dot_data)
graph

# %%
cv = GroupKFold(n_splits=10)
modelo = DecisionTreeClassifier(max_depth=10)
results = cross_validate(modelo, x_azar, y_azar, cv=cv, groups=dados.modelo, return_train_score=False)
imprime_resultados(results)
# Out:
# Accuracy médio 76.90
# Intervalo [74.02, 79.78]

# %% [markdown]
# # Testando parâmetros

# %%
def roda_arvore_de_decisao(max_depth):
  SEED = 301
  np.random.seed(SEED)

  cv = GroupKFold(n_splits=10)
  modelo = DecisionTreeClassifier(max_depth=max_depth)
  results = cross_validate(modelo, x_azar, y_azar, cv=cv, groups=dados.modelo, return_train_score=True)

  train_score = results["train_score"].mean() * 100
  test_score = results["test_score"].mean() * 100
  # print("Árvore max_depth = %d, treino = %.2f, teste = %.2f" % (max_depth, train_score, test_score))

  tabela = [max_depth, train_score, test_score]
  return tabela

resultados = [roda_arvore_de_decisao(i) for i in range(1, 33)]
resultados = pd.DataFrame(resultados, columns=["max_depth", "train", "test"])
resultados.head()
# Out:
#    max_depth      train       test
# 0          1  75.791101  75.779083
# 1          2  75.791101  75.779083
# 2          3  78.755605  78.673716
# 3          4  78.793388  78.604045
# 4          5  78.935592  78.596576

# %% [markdown]
# # OVERFIT: ficou "perfeito" para o treino mas ruim para o teste

# %%
import seaborn as sns

sns.lineplot(x = "max_depth", y = "train", data = resultados)

# %%
sns.lineplot(x = "max_depth", y = "test", data = resultados)

# %%
import matplotlib.pyplot as plt

sns.lineplot(x = "max_depth", y = "train", data = resultados)
sns.lineplot(x = "max_depth", y = "test", data = resultados)
plt.legend(["Treino", "Teste"])

# %%
resultados.sort_values("test", ascending=False).head()
# Out:
#    max_depth      train       test
# 2          3  78.755605  78.673716
# 3          4  78.793388  78.604045
# 4          5  78.935592  78.596576
# 5          6  79.185673  78.467568
# 6          7  79.484727  78.083640

# %% [markdown]
# # Explorando hiper parâmetros em 2 dimensões

# %%
def roda_arvore_de_decisao(max_depth, min_samples_leaf):
  SEED = 301
  np.random.seed(SEED)

  cv = GroupKFold(n_splits=10)
  modelo = DecisionTreeClassifier(max_depth=max_depth, min_samples_leaf=min_samples_leaf)
  results = cross_validate(modelo, x_azar, y_azar, cv=cv, groups=dados.modelo, return_train_score=True)

  train_score = results["train_score"].mean() * 100
  test_score = results["test_score"].mean() * 100
  print("Árvore max_depth = %d, min_samples_leaf = %d, treino = %.2f, teste = %.2f" % (max_depth, min_samples_leaf, train_score, test_score))

  tabela = [max_depth, min_samples_leaf, train_score, test_score]
  return tabela

def busca():
  resultados = []
  for max_depth in range(1,33):
    for min_samples_leaf in [32, 64, 128, 256]:
      tabela = roda_arvore_de_decisao(max_depth, min_samples_leaf)
      resultados.append(tabela)
  resultados = pd.DataFrame(resultados, columns=["max_depth", "min_samples_leaf", "train", "test"])
  return resultados

resultados = busca()
resultados.head()
# Out:
# Árvore max_depth = 1, min_samples_leaf = 32, treino = 75.79, teste = 75.78
# Árvore max_depth = 1, min_samples_leaf = 64, treino = 75.79, teste = 75.78
# Árvore max_depth = 1, min_samples_leaf = 128, treino = 75.79, teste = 75.78
# Árvore max_depth = 1, min_samples_leaf = 256, treino = 75.79, teste = 75.78
# Árvore max_depth = 2, min_samples_leaf = 32, treino = 75.79, teste = 75.78
# Árvore max_depth = 2, min_samples_leaf = 64, treino = 75.79, teste = 75.78
# Árvore max_depth = 2, min_samples_leaf = 128, treino = 75.79, teste = 75.78
# Árvore max_depth = 2, min_samples_leaf = 256, treino = 75.79, teste = 75.78
# Árvore max_depth = 3, min_samples_leaf = 32, treino = 78.75, teste = 78.67
# Árvore max_depth = 3, min_samples_leaf = 64, treino = 78.75, teste = 78.67
# Árvore max_depth = 3, min_samples_leaf = 128, treino = 78.75, teste = 78.67
# Árvore max_depth = 3, min_samples_leaf = 256, treino = 78.75, teste = 78.67
# Árvore max_depth = 4, min_samples_leaf = 32, treino = 78.75, teste = 78.67
# Árvore max_depth = 4, min_samples_leaf = 64, treino = 78.75, teste = 78.67
# Árvore max_depth = 4, min_samples_leaf = 128, treino = 78.75, teste = 78.67
# Árvore max_depth = 4, min_samples_leaf = 256, treino = 78.75, teste = 78.67
# Árvore max_depth = 5, min_samples_leaf = 32, treino = 78.80, teste = 78.32
# Árvore max_depth = 5, min_samples_leaf = 64, treino = 78.78, teste = 78.36
# Árvore max_depth = 5, min_samples_leaf = 128, treino = 78.78, teste = 78.35
# Árvore max_depth = 5, min_samples_leaf = 256, treino = 78.78, teste = 78.35
# Árvore max_depth = 6, min_samples_leaf = 32, treino = 78.92, teste = 78.30
# Árvore max_depth = 6, min_samples_leaf = 64, treino = 78.89, teste = 78.23
# Árvore max_depth = 6, min_samples_leaf = 128, treino = 78.89, teste = 78.15
# Árvore max_depth = 6, min_samples_leaf = 256, treino = 78.80, teste = 78.36
# Árvore max_depth = 7, min_samples_leaf = 32, treino = 79.17, teste = 77.80
# Árvore max_depth = 7, min_samples_leaf = 64, treino = 79.10, teste = 78.19
# Árvore max_depth = 7, min_samples_leaf = 128, treino = 79.05, teste = 78.11
# Árvore max_depth = 7, min_samples_leaf = 256, treino = 78.88, teste = 78.30
# Árvore max_depth = 8, min_samples_leaf = 32, treino = 79.42, teste = 77.76
# Árvore max_depth = 8, min_samples_leaf = 64, treino = 79.35, teste = 77.67
# Árvore max_depth = 8, min_samples_leaf = 128, treino = 79.09, teste = 78.06
# Árvore max_depth = 8, min_samples_leaf = 256, treino = 78.89, teste = 78.19
# Árvore max_depth = 9, min_samples_leaf = 32, treino = 79.73, teste = 77.74
# Árvore max_depth = 9, min_samples_leaf = 64, treino = 79.47, teste = 77.81
# Árvore max_depth = 9, min_samples_leaf = 128, treino = 79.11, teste = 78.07
# Árvore max_depth = 9, min_samples_leaf = 256, treino = 78.90, teste = 78.18
# Árvore max_depth = 10, min_samples_leaf = 32, treino = 79.86, teste = 77.72
# Árvore max_depth = 10, min_samples_leaf = 64, treino = 79.52, teste = 77.43
# Árvore max_depth = 10, min_samples_leaf = 128, treino = 79.17, teste = 77.85
# Árvore max_depth = 10, min_samples_leaf = 256, treino = 78.90, teste = 78.18
# Árvore max_depth = 11, min_samples_leaf = 32, treino = 80.09, teste = 77.49
# Árvore max_depth = 11, min_samples_leaf = 64, treino = 79.67, teste = 77.34
# Árvore max_depth = 11, min_samples_leaf = 128, treino = 79.21, teste = 77.82
# Árvore max_depth = 11, min_samples_leaf = 256, treino = 78.90, teste = 78.18
# Árvore max_depth = 12, min_samples_leaf = 32, treino = 80.21, teste = 77.26
# Árvore max_depth = 12, min_samples_leaf = 64, treino = 79.75, teste = 77.15
# Árvore max_depth = 12, min_samples_leaf = 128, treino = 79.21, teste = 77.82
# Árvore max_depth = 12, min_samples_leaf = 256, treino = 78.90, teste = 78.18
# Árvore max_depth = 13, min_samples_leaf = 32, treino = 80.39, teste = 77.43
# Árvore max_depth = 13, min_samples_leaf = 64, treino = 79.80, teste = 77.11
# Árvore max_depth = 13, min_samples_leaf = 128, treino = 79.21, teste = 77.82
# Árvore max_depth = 13, min_samples_leaf = 256, treino = 78.90, teste = 78.18
# Árvore max_depth = 14, min_samples_leaf = 32, treino = 80.48, teste = 77.29
# Árvore max_depth = 14, min_samples_leaf = 64, treino = 79.82, teste = 77.14
# Árvore max_depth = 14, min_samples_leaf = 128, treino = 79.21, teste = 77.82
# Árvore max_depth = 14, min_samples_leaf = 256, treino = 78.90, teste = 78.18
# Árvore max_depth = 15, min_samples_leaf = 32, treino = 80.61, teste = 77.22
# Árvore max_depth = 15, min_samples_leaf = 64, treino = 79.85, teste = 77.17
# Árvore max_depth = 15, min_samples_leaf = 128, treino = 79.21, teste = 77.82
# Árvore max_depth = 15, min_samples_leaf = 256, treino = 78.90, teste = 78.18
# Árvore max_depth = 16, min_samples_leaf = 32, treino = 80.69, teste = 77.18
# Árvore max_depth = 16, min_samples_leaf = 64, treino = 79.86, teste = 77.16
# Árvore max_depth = 16, min_samples_leaf = 128, treino = 79.21, teste = 77.82
# Árvore max_depth = 16, min_samples_leaf = 256, treino = 78.90, teste = 78.18
# Árvore max_depth = 17, min_samples_leaf = 32, treino = 80.76, teste = 77.15
# Árvore max_depth = 17, min_samples_leaf = 64, treino = 79.86, teste = 77.16
# Árvore max_depth = 17, min_samples_leaf = 128, treino = 79.21, teste = 77.82
# Árvore max_depth = 17, min_samples_leaf = 256, treino = 78.90, teste = 78.18
# Árvore max_depth = 18, min_samples_leaf = 32, treino = 80.80, teste = 77.12
# Árvore max_depth = 18, min_samples_leaf = 64, treino = 79.86, teste = 77.16
# Árvore max_depth = 18, min_samples_leaf = 128, treino = 79.21, teste = 77.82
# Árvore max_depth = 18, min_samples_leaf = 256, treino = 78.90, teste = 78.18
# Árvore max_depth = 19, min_samples_leaf = 32, treino = 80.83, teste = 77.11
# Árvore max_depth = 19, min_samples_leaf = 64, treino = 79.86, teste = 77.16
# Árvore max_depth = 19, min_samples_leaf = 128, treino = 79.21, teste = 77.82
# Árvore max_depth = 19, min_samples_leaf = 256, treino = 78.90, teste = 78.18
# Árvore max_depth = 20, min_samples_leaf = 32, treino = 80.85, teste = 77.10
# Árvore max_depth = 20, min_samples_leaf = 64, treino = 79.86, teste = 77.16
# Árvore max_depth = 20, min_samples_leaf = 128, treino = 79.21, teste = 77.82
# Árvore max_depth = 20, min_samples_leaf = 256, treino = 78.90, teste = 78.18
# Árvore max_depth = 21, min_samples_leaf = 32, treino = 80.86, teste = 77.14
# Árvore max_depth = 21, min_samples_leaf = 64, treino = 79.86, teste = 77.16
# Árvore max_depth = 21, min_samples_leaf = 128, treino = 79.21, teste = 77.82
# Árvore max_depth = 21, min_samples_leaf = 256, treino = 78.90, teste = 78.18
# Árvore max_depth = 22, min_samples_leaf = 32, treino = 80.87, teste = 77.15
# Árvore max_depth = 22, min_samples_leaf = 64, treino = 79.86, teste = 77.16
# Árvore max_depth = 22, min_samples_leaf = 128, treino = 79.21, teste = 77.82
# Árvore max_depth = 22, min_samples_leaf = 256, treino = 78.90, teste = 78.18
# Árvore max_depth = 23, min_samples_leaf = 32, treino = 80.87, teste = 77.15
# Árvore max_depth = 23, min_samples_leaf = 64, treino = 79.86, teste = 77.16
# Árvore max_depth = 23, min_samples_leaf = 128, treino = 79.21, teste = 77.82
# Árvore max_depth = 23, min_samples_leaf = 256, treino = 78.90, teste = 78.18
# Árvore max_depth = 24, min_samples_leaf = 32, treino = 80.87, teste = 77.18
# Árvore max_depth = 24, min_samples_leaf = 64, treino = 79.86, teste = 77.16
# Árvore max_depth = 24, min_samples_leaf = 128, treino = 79.21, teste = 77.82
# Árvore max_depth = 24, min_samples_leaf = 256, treino = 78.90, teste = 78.18
# Árvore max_depth = 25, min_samples_leaf = 32, treino = 80.87, teste = 77.18
# Árvore max_depth = 25, min_samples_leaf = 64, treino = 79.86, teste = 77.16
# Árvore max_depth = 25, min_samples_leaf = 128, treino = 79.21, teste = 77.82
# Árvore max_depth = 25, min_samples_leaf = 256, treino = 78.90, teste = 78.18
# Árvore max_depth = 26, min_samples_leaf = 32, treino = 80.87, teste = 77.18
# Árvore max_depth = 26, min_samples_leaf = 64, treino = 79.86, teste = 77.16
# Árvore max_depth = 26, min_samples_leaf = 128, treino = 79.21, teste = 77.82
# Árvore max_depth = 26, min_samples_leaf = 256, treino = 78.90, teste = 78.18
# Árvore max_depth = 27, min_samples_leaf = 32, treino = 80.87, teste = 77.18
# Árvore max_depth = 27, min_samples_leaf = 64, treino = 79.86, teste = 77.16
# Árvore max_depth = 27, min_samples_leaf = 128, treino = 79.21, teste = 77.82
# Árvore max_depth = 27, min_samples_leaf = 256, treino = 78.90, teste = 78.18
# Árvore max_depth = 28, min_samples_leaf = 32, treino = 80.87, teste = 77.18
# Árvore max_depth = 28, min_samples_leaf = 64, treino = 79.86, teste = 77.16
# Árvore max_depth = 28, min_samples_leaf = 128, treino = 79.21, teste = 77.82
# Árvore max_depth = 28, min_samples_leaf = 256, treino = 78.90, teste = 78.18
# Árvore max_depth = 29, min_samples_leaf = 32, treino = 80.87, teste = 77.18
# Árvore max_depth = 29, min_samples_leaf = 64, treino = 79.86, teste = 77.16
# Árvore max_depth = 29, min_samples_leaf = 128, treino = 79.21, teste = 77.82
# Árvore max_depth = 29, min_samples_leaf = 256, treino = 78.90, teste = 78.18
# Árvore max_depth = 30, min_samples_leaf = 32, treino = 80.87, teste = 77.18
# Árvore max_depth = 30, min_samples_leaf = 64, treino = 79.86, teste = 77.16
# Árvore max_depth = 30, min_samples_leaf = 128, treino = 79.21, teste = 77.82
# Árvore max_depth = 30, min_samples_leaf = 256, treino = 78.90, teste = 78.18
# Árvore max_depth = 31, min_samples_leaf = 32, treino = 80.87, teste = 77.18
# Árvore max_depth = 31, min_samples_leaf = 64, treino = 79.86, teste = 77.16
# Árvore max_depth = 31, min_samples_leaf = 128, treino = 79.21, teste = 77.82
# Árvore max_depth = 31, min_samples_leaf = 256, treino = 78.90, teste = 78.18
# Árvore max_depth = 32, min_samples_leaf = 32, treino = 80.87, teste = 77.18
# Árvore max_depth = 32, min_samples_leaf = 64, treino = 79.86, teste = 77.16
# Árvore max_depth = 32, min_samples_leaf = 128, treino = 79.21, teste = 77.82
# Árvore max_depth = 32, min_samples_leaf = 256, treino = 78.90, teste = 78.18
#    max_depth  min_samples_leaf      train       test
# 0          1                32  75.791101  75.779083
# 1          1                64  75.791101  75.779083
# 2          1               128  75.791101  75.779083
# 3          1               256  75.791101  75.779083
# 4          2                32  75.791101  75.779083

# %%
resultados.sort_values("test", ascending=False).head()
# Out:
#     max_depth  min_samples_leaf      train       test
# 13          4                64  78.753381  78.673716
# 11          3               256  78.753381  78.673716
# 15          4               256  78.753381  78.673716
# 14          4               128  78.753381  78.673716
# 12          4                32  78.753381  78.673716

# %%
corr = resultados.corr()
corr
# Out:
#                   max_depth  min_samples_leaf     train      test
# max_depth          1.000000          0.000000  0.547410 -0.015495
# min_samples_leaf   0.000000          1.000000 -0.405657  0.450476
# train              0.547410         -0.405657  1.000000  0.193711
# test              -0.015495          0.450476  0.193711  1.000000

# %%
sns.heatmap(corr)

# %%
pd.plotting.scatter_matrix(resultados, figsize=(14, 8), alpha=0.3)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f7487895f60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7487854240>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f74878034a8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7487834710>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f74877e3978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7487796be0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7487747e48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f74877080b8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f7487708128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f74876ed5c0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f74876a3828>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7487656a90>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f7487608cf8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f74875bcf60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f748757d208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f74875b1470>]],
#       dtype=object)

# %%
sns.pairplot(resultados)

# %%
sns.set(style="white")

mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

f, ax = plt.subplots(figsize=(11, 9))

# cmap = sns.diverging_palette(220, 10, as_cmap=True)

# sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0, square=True, linewidths=.5, cbar_kws={"shrink": .5})
sns.heatmap(corr, mask=mask, vmax=.3, center=0, square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
def busca():
  resultados = []
  for max_depth in range(1,33):
    for min_samples_leaf in [128, 192, 256, 512]:
      tabela = roda_arvore_de_decisao(max_depth, min_samples_leaf)
      resultados.append(tabela)
  resultados = pd.DataFrame(resultados, columns=["max_depth", "min_samples_leaf", "train", "test"])
  return resultados

resultados = busca()
resultados.head()
# Out:
# Árvore max_depth = 1, min_samples_leaf = 128, treino = 75.79, teste = 75.78
# Árvore max_depth = 1, min_samples_leaf = 192, treino = 75.79, teste = 75.78
# Árvore max_depth = 1, min_samples_leaf = 256, treino = 75.79, teste = 75.78
# Árvore max_depth = 1, min_samples_leaf = 512, treino = 75.79, teste = 75.78
# Árvore max_depth = 2, min_samples_leaf = 128, treino = 75.79, teste = 75.78
# Árvore max_depth = 2, min_samples_leaf = 192, treino = 75.79, teste = 75.78
# Árvore max_depth = 2, min_samples_leaf = 256, treino = 75.79, teste = 75.78
# Árvore max_depth = 2, min_samples_leaf = 512, treino = 75.79, teste = 75.78
# Árvore max_depth = 3, min_samples_leaf = 128, treino = 78.75, teste = 78.67
# Árvore max_depth = 3, min_samples_leaf = 192, treino = 78.75, teste = 78.67
# Árvore max_depth = 3, min_samples_leaf = 256, treino = 78.75, teste = 78.67
# Árvore max_depth = 3, min_samples_leaf = 512, treino = 77.53, teste = 77.51
# Árvore max_depth = 4, min_samples_leaf = 128, treino = 78.75, teste = 78.67
# Árvore max_depth = 4, min_samples_leaf = 192, treino = 78.75, teste = 78.67
# Árvore max_depth = 4, min_samples_leaf = 256, treino = 78.75, teste = 78.67
# Árvore max_depth = 4, min_samples_leaf = 512, treino = 77.53, teste = 77.51
# Árvore max_depth = 5, min_samples_leaf = 128, treino = 78.78, teste = 78.35
# Árvore max_depth = 5, min_samples_leaf = 192, treino = 78.78, teste = 78.35
# Árvore max_depth = 5, min_samples_leaf = 256, treino = 78.78, teste = 78.35
# Árvore max_depth = 5, min_samples_leaf = 512, treino = 77.53, teste = 77.51
# Árvore max_depth = 6, min_samples_leaf = 128, treino = 78.89, teste = 78.15
# Árvore max_depth = 6, min_samples_leaf = 192, treino = 78.83, teste = 78.26
# Árvore max_depth = 6, min_samples_leaf = 256, treino = 78.80, teste = 78.36
# Árvore max_depth = 6, min_samples_leaf = 512, treino = 77.53, teste = 77.51
# Árvore max_depth = 7, min_samples_leaf = 128, treino = 79.05, teste = 78.11
# Árvore max_depth = 7, min_samples_leaf = 192, treino = 78.94, teste = 78.23
# Árvore max_depth = 7, min_samples_leaf = 256, treino = 78.88, teste = 78.30
# Árvore max_depth = 7, min_samples_leaf = 512, treino = 77.53, teste = 77.51
# Árvore max_depth = 8, min_samples_leaf = 128, treino = 79.09, teste = 78.06
# Árvore max_depth = 8, min_samples_leaf = 192, treino = 78.96, teste = 77.87
# Árvore max_depth = 8, min_samples_leaf = 256, treino = 78.89, teste = 78.19
# Árvore max_depth = 8, min_samples_leaf = 512, treino = 77.53, teste = 77.51
# Árvore max_depth = 9, min_samples_leaf = 128, treino = 79.11, teste = 78.07
# Árvore max_depth = 9, min_samples_leaf = 192, treino = 78.98, teste = 77.88
# Árvore max_depth = 9, min_samples_leaf = 256, treino = 78.90, teste = 78.18
# Árvore max_depth = 9, min_samples_leaf = 512, treino = 77.53, teste = 77.51
# Árvore max_depth = 10, min_samples_leaf = 128, treino = 79.17, teste = 77.85
# Árvore max_depth = 10, min_samples_leaf = 192, treino = 78.99, teste = 77.83
# Árvore max_depth = 10, min_samples_leaf = 256, treino = 78.90, teste = 78.18
# Árvore max_depth = 10, min_samples_leaf = 512, treino = 77.53, teste = 77.51
# Árvore max_depth = 11, min_samples_leaf = 128, treino = 79.21, teste = 77.82
# Árvore max_depth = 11, min_samples_leaf = 192, treino = 78.99, teste = 77.83
# Árvore max_depth = 11, min_samples_leaf = 256, treino = 78.90, teste = 78.18
# Árvore max_depth = 11, min_samples_leaf = 512, treino = 77.53, teste = 77.51
# Árvore max_depth = 12, min_samples_leaf = 128, treino = 79.21, teste = 77.82
# Árvore max_depth = 12, min_samples_leaf = 192, treino = 78.99, teste = 77.83
# Árvore max_depth = 12, min_samples_leaf = 256, treino = 78.90, teste = 78.18
# Árvore max_depth = 12, min_samples_leaf = 512, treino = 77.53, teste = 77.51
# Árvore max_depth = 13, min_samples_leaf = 128, treino = 79.21, teste = 77.82
# Árvore max_depth = 13, min_samples_leaf = 192, treino = 78.99, teste = 77.83
# Árvore max_depth = 13, min_samples_leaf = 256, treino = 78.90, teste = 78.18
# Árvore max_depth = 13, min_samples_leaf = 512, treino = 77.53, teste = 77.51
# Árvore max_depth = 14, min_samples_leaf = 128, treino = 79.21, teste = 77.82
# Árvore max_depth = 14, min_samples_leaf = 192, treino = 78.99, teste = 77.83
# Árvore max_depth = 14, min_samples_leaf = 256, treino = 78.90, teste = 78.18
# Árvore max_depth = 14, min_samples_leaf = 512, treino = 77.53, teste = 77.51
# Árvore max_depth = 15, min_samples_leaf = 128, treino = 79.21, teste = 77.82
# Árvore max_depth = 15, min_samples_leaf = 192, treino = 78.99, teste = 77.83
# Árvore max_depth = 15, min_samples_leaf = 256, treino = 78.90, teste = 78.18
# Árvore max_depth = 15, min_samples_leaf = 512, treino = 77.53, teste = 77.51
# Árvore max_depth = 16, min_samples_leaf = 128, treino = 79.21, teste = 77.82
# Árvore max_depth = 16, min_samples_leaf = 192, treino = 78.99, teste = 77.83
# Árvore max_depth = 16, min_samples_leaf = 256, treino = 78.90, teste = 78.18
# Árvore max_depth = 16, min_samples_leaf = 512, treino = 77.53, teste = 77.51
# Árvore max_depth = 17, min_samples_leaf = 128, treino = 79.21, teste = 77.82
# Árvore max_depth = 17, min_samples_leaf = 192, treino = 78.99, teste = 77.83
# Árvore max_depth = 17, min_samples_leaf = 256, treino = 78.90, teste = 78.18
# Árvore max_depth = 17, min_samples_leaf = 512, treino = 77.53, teste = 77.51
# Árvore max_depth = 18, min_samples_leaf = 128, treino = 79.21, teste = 77.82
# Árvore max_depth = 18, min_samples_leaf = 192, treino = 78.99, teste = 77.83
# Árvore max_depth = 18, min_samples_leaf = 256, treino = 78.90, teste = 78.18
# Árvore max_depth = 18, min_samples_leaf = 512, treino = 77.53, teste = 77.51
# Árvore max_depth = 19, min_samples_leaf = 128, treino = 79.21, teste = 77.82
# Árvore max_depth = 19, min_samples_leaf = 192, treino = 78.99, teste = 77.83
# Árvore max_depth = 19, min_samples_leaf = 256, treino = 78.90, teste = 78.18
# Árvore max_depth = 19, min_samples_leaf = 512, treino = 77.53, teste = 77.51
# Árvore max_depth = 20, min_samples_leaf = 128, treino = 79.21, teste = 77.82
# Árvore max_depth = 20, min_samples_leaf = 192, treino = 78.99, teste = 77.83
# Árvore max_depth = 20, min_samples_leaf = 256, treino = 78.90, teste = 78.18
# Árvore max_depth = 20, min_samples_leaf = 512, treino = 77.53, teste = 77.51
# Árvore max_depth = 21, min_samples_leaf = 128, treino = 79.21, teste = 77.82
# Árvore max_depth = 21, min_samples_leaf = 192, treino = 78.99, teste = 77.83
# Árvore max_depth = 21, min_samples_leaf = 256, treino = 78.90, teste = 78.18
# Árvore max_depth = 21, min_samples_leaf = 512, treino = 77.53, teste = 77.51
# Árvore max_depth = 22, min_samples_leaf = 128, treino = 79.21, teste = 77.82
# Árvore max_depth = 22, min_samples_leaf = 192, treino = 78.99, teste = 77.83
# Árvore max_depth = 22, min_samples_leaf = 256, treino = 78.90, teste = 78.18
# Árvore max_depth = 22, min_samples_leaf = 512, treino = 77.53, teste = 77.51
# Árvore max_depth = 23, min_samples_leaf = 128, treino = 79.21, teste = 77.82
# Árvore max_depth = 23, min_samples_leaf = 192, treino = 78.99, teste = 77.83
# Árvore max_depth = 23, min_samples_leaf = 256, treino = 78.90, teste = 78.18
# Árvore max_depth = 23, min_samples_leaf = 512, treino = 77.53, teste = 77.51
# Árvore max_depth = 24, min_samples_leaf = 128, treino = 79.21, teste = 77.82
# Árvore max_depth = 24, min_samples_leaf = 192, treino = 78.99, teste = 77.83
# Árvore max_depth = 24, min_samples_leaf = 256, treino = 78.90, teste = 78.18
# Árvore max_depth = 24, min_samples_leaf = 512, treino = 77.53, teste = 77.51
# Árvore max_depth = 25, min_samples_leaf = 128, treino = 79.21, teste = 77.82
# Árvore max_depth = 25, min_samples_leaf = 192, treino = 78.99, teste = 77.83
# Árvore max_depth = 25, min_samples_leaf = 256, treino = 78.90, teste = 78.18
# Árvore max_depth = 25, min_samples_leaf = 512, treino = 77.53, teste = 77.51
# Árvore max_depth = 26, min_samples_leaf = 128, treino = 79.21, teste = 77.82
# Árvore max_depth = 26, min_samples_leaf = 192, treino = 78.99, teste = 77.83
# Árvore max_depth = 26, min_samples_leaf = 256, treino = 78.90, teste = 78.18
# Árvore max_depth = 26, min_samples_leaf = 512, treino = 77.53, teste = 77.51
# Árvore max_depth = 27, min_samples_leaf = 128, treino = 79.21, teste = 77.82
# Árvore max_depth = 27, min_samples_leaf = 192, treino = 78.99, teste = 77.83
# Árvore max_depth = 27, min_samples_leaf = 256, treino = 78.90, teste = 78.18
# Árvore max_depth = 27, min_samples_leaf = 512, treino = 77.53, teste = 77.51
# Árvore max_depth = 28, min_samples_leaf = 128, treino = 79.21, teste = 77.82
# Árvore max_depth = 28, min_samples_leaf = 192, treino = 78.99, teste = 77.83
# Árvore max_depth = 28, min_samples_leaf = 256, treino = 78.90, teste = 78.18
# Árvore max_depth = 28, min_samples_leaf = 512, treino = 77.53, teste = 77.51
# Árvore max_depth = 29, min_samples_leaf = 128, treino = 79.21, teste = 77.82
# Árvore max_depth = 29, min_samples_leaf = 192, treino = 78.99, teste = 77.83
# Árvore max_depth = 29, min_samples_leaf = 256, treino = 78.90, teste = 78.18
# Árvore max_depth = 29, min_samples_leaf = 512, treino = 77.53, teste = 77.51
# Árvore max_depth = 30, min_samples_leaf = 128, treino = 79.21, teste = 77.82
# Árvore max_depth = 30, min_samples_leaf = 192, treino = 78.99, teste = 77.83
# Árvore max_depth = 30, min_samples_leaf = 256, treino = 78.90, teste = 78.18
# Árvore max_depth = 30, min_samples_leaf = 512, treino = 77.53, teste = 77.51
# Árvore max_depth = 31, min_samples_leaf = 128, treino = 79.21, teste = 77.82
# Árvore max_depth = 31, min_samples_leaf = 192, treino = 78.99, teste = 77.83
# Árvore max_depth = 31, min_samples_leaf = 256, treino = 78.90, teste = 78.18
# Árvore max_depth = 31, min_samples_leaf = 512, treino = 77.53, teste = 77.51
# Árvore max_depth = 32, min_samples_leaf = 128, treino = 79.21, teste = 77.82
# Árvore max_depth = 32, min_samples_leaf = 192, treino = 78.99, teste = 77.83
# Árvore max_depth = 32, min_samples_leaf = 256, treino = 78.90, teste = 78.18
# Árvore max_depth = 32, min_samples_leaf = 512, treino = 77.53, teste = 77.51
#    max_depth  min_samples_leaf      train       test
# 0          1               128  75.791101  75.779083
# 1          1               192  75.791101  75.779083
# 2          1               256  75.791101  75.779083
# 3          1               512  75.791101  75.779083
# 4          2               128  75.791101  75.779083

# %%
corr = resultados.corr()

sns.set(style="white")

mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

f, ax = plt.subplots(figsize=(11, 9))

# cmap = sns.diverging_palette(220, 10, as_cmap=True)

# sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0, square=True, linewidths=.5, cbar_kws={"shrink": .5})
sns.heatmap(corr, mask=mask, vmax=.3, center=0, square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
resultados.sort_values("test", ascending=False).head()
# Out:
#     max_depth  min_samples_leaf      train       test
# 14          4               256  78.753381  78.673716
# 8           3               128  78.753381  78.673716
# 13          4               192  78.753381  78.673716
# 12          4               128  78.753381  78.673716
# 10          3               256  78.753381  78.673716

# %% [markdown]
# # Explorando 3 dimensões de hiper parâmetros

# %%
def roda_arvore_de_decisao(max_depth, min_samples_leaf, min_samples_split):
  SEED = 301
  np.random.seed(SEED)

  cv = GroupKFold(n_splits=10)
  modelo = DecisionTreeClassifier(max_depth=max_depth, min_samples_leaf=min_samples_leaf, min_samples_split=min_samples_split)
  results = cross_validate(modelo, x_azar, y_azar, cv=cv, groups=dados.modelo, return_train_score=True)

  train_score = results["train_score"].mean() * 100
  test_score = results["test_score"].mean() * 100
  fit_time = results["fit_time"].mean()
  score_time = results["score_time"].mean()

  tabela = [max_depth, min_samples_leaf, min_samples_split, train_score, test_score, fit_time, score_time]
  return tabela

def busca():
  resultados = []
  for max_depth in range(1,33):
    for min_samples_leaf in [32, 64, 128, 256]:
      for min_samples_split in [32, 64, 128, 256]:
        tabela = roda_arvore_de_decisao(max_depth, min_samples_leaf, min_samples_split)
        resultados.append(tabela)
  resultados = pd.DataFrame(resultados, columns=["max_depth", "min_samples_leaf", "min_samples_split", "train", "test", "fit_time", "score_time"])
  return resultados

resultados = busca()
resultados.head()
# Out:
#    max_depth  min_samples_leaf  ...  fit_time  score_time
# 0          1                32  ...  0.005613    0.001146
# 1          1                32  ...  0.005170    0.001044
# 2          1                32  ...  0.005099    0.001034
# 3          1                32  ...  0.004988    0.000993
# 4          1                64  ...  0.005100    0.001043
#
# [5 rows x 7 columns]

# %%
corr = resultados.corr()

sns.set(style="white")

mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

f, ax = plt.subplots(figsize=(11, 9))

# cmap = sns.diverging_palette(220, 10, as_cmap=True)

# sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0, square=True, linewidths=.5, cbar_kws={"shrink": .5})
sns.heatmap(corr, mask=mask, vmax=.3, center=0, square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
resultados.sort_values("test", ascending=False).head()
# Out:
#     max_depth  min_samples_leaf  ...  fit_time  score_time
# 36          3                64  ...  0.010285    0.001134
# 37          3                64  ...  0.010600    0.001308
# 49          4                32  ...  0.011765    0.001094
# 48          4                32  ...  0.011708    0.001055
# 47          3               256  ...  0.009621    0.001030
#
# [5 rows x 7 columns]

# %% [markdown]
# # Explorando espaço de hiper parâmetros com GridSearchCV

# %%
from sklearn.model_selection import GridSearchCV

SEED = 301
np.random.seed(SEED)

espaco_de_parametros = {
    "max_depth" : [3, 5],
    "min_samples_split": [32, 64, 128],
    "min_samples_leaf": [32, 64, 128],
    "criterion": ["gini", "entropy"]
}

busca = GridSearchCV(DecisionTreeClassifier(), espaco_de_parametros, cv=GroupKFold(n_splits=10))
busca.fit(x_azar, y_azar, groups=dados.modelo)
resultados = pd.DataFrame(busca.cv_results_)
resultados.head()
# Out:
#    mean_fit_time  std_fit_time  ...  std_test_score  rank_test_score
# 0       0.010024      0.000588  ...        0.016783                1
# 1       0.010452      0.001295  ...        0.016783                1
# 2       0.010036      0.000548  ...        0.016783                1
# 3       0.009858      0.000098  ...        0.016783                1
# 4       0.009910      0.000125  ...        0.016783                1
#
# [5 rows x 22 columns]

# %%
print(busca.best_params_)
print(busca.best_score_ * 100)
# Out:
# {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 32, 'min_samples_split': 32}
# 78.67371606412836

# %%
melhor = busca.best_estimator_
melhor
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=3, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=32, min_samples_split=32,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
from sklearn.metrics import accuracy_score

# evitar essa abordagem pois estará sendo otimista (dados já vistos)

predicoes = melhor.predict(x_azar)
accuracy = accuracy_score(predicoes, y_azar) * 100
print("Accuracy para os dados foi %.2f%%" % accuracy)
# Out:
# Accuracy para os dados foi 78.75%

# %% [markdown]
# # Como ter uma estimativa sem esse vício nos dados que eu já vi?
# No caso de cross validation com busca de hiper parâmetros, fazemos uma nova validação cruzada. Chama-se nested cross validation.

# %%
from sklearn.model_selection import cross_val_score

cross_val_score(busca, x_azar, y_azar, cv=GroupKFold(n_splits=10), groups=dados.modelo)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: The 'groups' parameter should not be None.
#
#   FitFailedWarning)
# array([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan])

# %% [markdown]
# # Infelizmente como o Pandas não suporta nested validation com group k fold não conseguimos prever o resultado para novos grupos

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import KFold

SEED = 301
np.random.seed(SEED)

espaco_de_parametros = {
    "max_depth" : [3, 5],
    "min_samples_split": [32, 64, 128],
    "min_samples_leaf": [32, 64, 128],
    "criterion": ["gini", "entropy"]
}

busca = GridSearchCV(DecisionTreeClassifier(), espaco_de_parametros, cv=KFold(n_splits=5, shuffle=True))
busca.fit(x_azar, y_azar)
resultados = pd.DataFrame(busca.cv_results_)
resultados.head()
# Out:
#    mean_fit_time  std_fit_time  ...  std_test_score  rank_test_score
# 0       0.009480      0.001124  ...        0.009618                1
# 1       0.008880      0.000077  ...        0.009618                1
# 2       0.008985      0.000115  ...        0.009618                1
# 3       0.009634      0.001427  ...        0.009618                1
# 4       0.008850      0.000103  ...        0.009618                1
#
# [5 rows x 17 columns]

# %%
from sklearn.model_selection import cross_val_score

scores = cross_val_score(busca, x_azar, y_azar, cv=KFold(n_splits=5, shuffle=True))
scores
# Out:
# array([0.7895, 0.7825, 0.7905, 0.7715, 0.7995])

# %%
def imprime_score(scores):
  media = scores.mean() * 100
  desvio = scores.std() * 100
  print("Accuracy médio %.2f" % media)
  print("Intervalo [%.2f, %.2f]" % (media - 2 * desvio, media + 2 * desvio))

imprime_score(scores)
# Out:
# Accuracy médio 78.67
# Intervalo [76.80, 80.54]

# %%
melhor = busca.best_estimator_
melhor
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=3, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=32, min_samples_split=32,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
from sklearn.tree import export_graphviz
import graphviz

features = x_azar.columns
dot_data = export_graphviz(melhor, out_file=None, filled=True, rounded=True, class_names=["não", "sim"], feature_names=features)
graph = graphviz.Source(dot_data)
graph

# %% [markdown]
# # Busca aleatória: RandomSearch

# %%
from sklearn.model_selection import RandomizedSearchCV, KFold

SEED = 301
np.random.seed(SEED)

espaco_de_parametros = {
    "max_depth" : [3, 5],
    "min_samples_split": [32, 64, 128],
    "min_samples_leaf": [32, 64, 128],
    "criterion": ["gini", "entropy"]
}

busca = RandomizedSearchCV(DecisionTreeClassifier(), espaco_de_parametros, cv=KFold(n_splits=5, shuffle=True), random_state=SEED, n_iter=16)
busca.fit(x_azar, y_azar)
resultados = pd.DataFrame(busca.cv_results_)
resultados.head()
# Out:
#    mean_fit_time  std_fit_time  ...  std_test_score  rank_test_score
# 0       0.012842      0.001346  ...        0.011278               13
# 1       0.008816      0.000074  ...        0.009618                1
# 2       0.008906      0.000099  ...        0.009618                1
# 3       0.020482      0.001906  ...        0.011825                7
# 4       0.019184      0.000645  ...        0.011825                7
#
# [5 rows x 17 columns]

# %%
scores = cross_val_score(busca, x_azar, y_azar, cv=KFold(n_splits=5, shuffle=True))
imprime_score(scores)
# Out:
# Accuracy médio 78.71
# Intervalo [77.49, 79.93]

# %%
melhor = busca.best_estimator_
print(melhor)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=3, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=32, min_samples_split=64,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
features = x_azar.columns
dot_data = export_graphviz(melhor, out_file=None, filled=True, rounded=True, class_names=["não", "sim"], feature_names=features)
graph = graphviz.Source(dot_data)
graph

# %% [markdown]
# # Customizando o espaço de hiper parâmetros

# %%
from scipy.stats import randint

SEED = 301
np.random.seed(SEED)

espaco_de_parametros = {
    "max_depth" : [3, 5, 10, 15, 20, 30, None],
    "min_samples_split": randint(32, 128),
    "min_samples_leaf": randint(32, 128),
    "criterion": ["gini", "entropy"]
}

busca = RandomizedSearchCV(DecisionTreeClassifier(), espaco_de_parametros, cv=KFold(n_splits=5, shuffle=True), random_state=SEED, n_iter=16)
busca.fit(x_azar, y_azar)
resultados = pd.DataFrame(busca.cv_results_)
resultados.head()
# Out:
#    mean_fit_time  std_fit_time  ...  std_test_score  rank_test_score
# 0       0.013485      0.000348  ...        0.009618                1
# 1       0.016811      0.000378  ...        0.004393               14
# 2       0.015738      0.000611  ...        0.010221                8
# 3       0.021167      0.001741  ...        0.010378               16
# 4       0.015344      0.000438  ...        0.010413                7
#
# [5 rows x 17 columns]

# %%
scores = cross_val_score(busca, x_azar, y_azar, cv=KFold(n_splits=5, shuffle=True))
imprime_score(scores)
# Out:
# Accuracy médio 78.71
# Intervalo [77.49, 79.93]

# %%
melhor = busca.best_estimator_
print(melhor)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='entropy',
#                        max_depth=3, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=71, min_samples_split=100,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
resultados_ordenados_pela_media = resultados.sort_values('mean_test_score', ascending=False)

for indice, linha in resultados_ordenados_pela_media.iterrows():
  print('%.3f +-(%.3f) %s' % (linha.mean_test_score, linha.std_test_score * 2, linha.params))
# Out:
# 0.787 +-(0.019) {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 71, 'min_samples_split': 100}
# 0.784 +-(0.024) {'criterion': 'entropy', 'max_depth': 5, 'min_samples_leaf': 73, 'min_samples_split': 72}
# 0.784 +-(0.024) {'criterion': 'gini', 'max_depth': 5, 'min_samples_leaf': 64, 'min_samples_split': 67}
# 0.781 +-(0.017) {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 108, 'min_samples_split': 110}
# 0.780 +-(0.019) {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 125, 'min_samples_split': 59}
# 0.780 +-(0.012) {'criterion': 'gini', 'max_depth': 15, 'min_samples_leaf': 103, 'min_samples_split': 96}
# 0.779 +-(0.021) {'criterion': 'gini', 'max_depth': 15, 'min_samples_leaf': 126, 'min_samples_split': 84}
# 0.779 +-(0.020) {'criterion': 'gini', 'max_depth': 20, 'min_samples_leaf': 124, 'min_samples_split': 88}
# 0.779 +-(0.009) {'criterion': 'gini', 'max_depth': None, 'min_samples_leaf': 101, 'min_samples_split': 52}
# 0.779 +-(0.014) {'criterion': 'entropy', 'max_depth': 15, 'min_samples_leaf': 104, 'min_samples_split': 88}
# 0.779 +-(0.010) {'criterion': 'gini', 'max_depth': 30, 'min_samples_leaf': 100, 'min_samples_split': 84}
# 0.778 +-(0.014) {'criterion': 'entropy', 'max_depth': 30, 'min_samples_leaf': 74, 'min_samples_split': 58}
# 0.777 +-(0.013) {'criterion': 'gini', 'max_depth': 30, 'min_samples_leaf': 88, 'min_samples_split': 78}
# 0.776 +-(0.009) {'criterion': 'gini', 'max_depth': 15, 'min_samples_leaf': 93, 'min_samples_split': 111}
# 0.775 +-(0.015) {'criterion': 'entropy', 'max_depth': 20, 'min_samples_leaf': 52, 'min_samples_split': 80}
# 0.769 +-(0.021) {'criterion': 'gini', 'max_depth': None, 'min_samples_leaf': 46, 'min_samples_split': 62}

# %% [markdown]
# # Uma exploração mais a fundo de forma aleatória

# %%
SEED = 564
np.random.seed(SEED)

espaco_de_parametros = {
    "max_depth" : [3, 5, 10, 15, 20, 30, None],
    "min_samples_split": randint(32, 128),
    "min_samples_leaf": randint(32, 128),
    "criterion": ["gini", "entropy"]
}

busca = RandomizedSearchCV(DecisionTreeClassifier(), espaco_de_parametros, cv=KFold(n_splits=5, shuffle=True), random_state=SEED, n_iter=64)
busca.fit(x_azar, y_azar)
resultados = pd.DataFrame(busca.cv_results_)
resultados.head()
# Out:
#    mean_fit_time  std_fit_time  ...  std_test_score  rank_test_score
# 0       0.028220      0.001827  ...        0.006583               62
# 1       0.009045      0.000139  ...        0.005607                1
# 2       0.015614      0.000225  ...        0.005273               18
# 3       0.030683      0.000557  ...        0.005295               57
# 4       0.018063      0.000287  ...        0.004669               29
#
# [5 rows x 17 columns]

# %%
resultados_ordenados_pela_media = resultados.sort_values('mean_test_score', ascending=False)

for indice, linha in resultados_ordenados_pela_media.iterrows():
  print('%.3f +-(%.3f) %s' % (linha.mean_test_score, linha.std_test_score * 2, linha.params))
# Out:
# 0.787 +-(0.011) {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 33, 'min_samples_split': 77}
# 0.787 +-(0.011) {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 38, 'min_samples_split': 113}
# 0.787 +-(0.011) {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 53, 'min_samples_split': 60}
# 0.787 +-(0.011) {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 61, 'min_samples_split': 86}
# 0.787 +-(0.011) {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 49, 'min_samples_split': 58}
# 0.787 +-(0.011) {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 58, 'min_samples_split': 118}
# 0.787 +-(0.011) {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 122, 'min_samples_split': 117}
# 0.786 +-(0.013) {'criterion': 'gini', 'max_depth': 5, 'min_samples_leaf': 39, 'min_samples_split': 73}
# 0.786 +-(0.013) {'criterion': 'entropy', 'max_depth': 5, 'min_samples_leaf': 45, 'min_samples_split': 65}
# 0.786 +-(0.014) {'criterion': 'entropy', 'max_depth': 5, 'min_samples_leaf': 101, 'min_samples_split': 59}
# 0.786 +-(0.013) {'criterion': 'entropy', 'max_depth': 5, 'min_samples_leaf': 67, 'min_samples_split': 82}
# 0.786 +-(0.014) {'criterion': 'gini', 'max_depth': 5, 'min_samples_leaf': 80, 'min_samples_split': 60}
# 0.786 +-(0.014) {'criterion': 'gini', 'max_depth': 5, 'min_samples_leaf': 85, 'min_samples_split': 121}
# 0.779 +-(0.009) {'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 115, 'min_samples_split': 90}
# 0.779 +-(0.010) {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 43, 'min_samples_split': 97}
# 0.778 +-(0.009) {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 105, 'min_samples_split': 107}
# 0.778 +-(0.014) {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 127, 'min_samples_split': 96}
# 0.778 +-(0.011) {'criterion': 'gini', 'max_depth': None, 'min_samples_leaf': 121, 'min_samples_split': 50}
# 0.778 +-(0.011) {'criterion': 'gini', 'max_depth': 30, 'min_samples_leaf': 118, 'min_samples_split': 61}
# 0.778 +-(0.011) {'criterion': 'entropy', 'max_depth': 15, 'min_samples_leaf': 117, 'min_samples_split': 122}
# 0.778 +-(0.011) {'criterion': 'gini', 'max_depth': 15, 'min_samples_leaf': 121, 'min_samples_split': 103}
# 0.778 +-(0.011) {'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 118, 'min_samples_split': 116}
# 0.777 +-(0.012) {'criterion': 'entropy', 'max_depth': 15, 'min_samples_leaf': 123, 'min_samples_split': 71}
# 0.777 +-(0.013) {'criterion': 'entropy', 'max_depth': 15, 'min_samples_leaf': 125, 'min_samples_split': 84}
# 0.777 +-(0.013) {'criterion': 'entropy', 'max_depth': 20, 'min_samples_leaf': 126, 'min_samples_split': 104}
# 0.777 +-(0.012) {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 32, 'min_samples_split': 53}
# 0.776 +-(0.005) {'criterion': 'gini', 'max_depth': 20, 'min_samples_leaf': 108, 'min_samples_split': 45}
# 0.776 +-(0.007) {'criterion': 'gini', 'max_depth': 20, 'min_samples_leaf': 104, 'min_samples_split': 71}
# 0.776 +-(0.009) {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 44, 'min_samples_split': 67}
# 0.776 +-(0.014) {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 100, 'min_samples_split': 92}
# 0.776 +-(0.007) {'criterion': 'entropy', 'max_depth': 30, 'min_samples_leaf': 109, 'min_samples_split': 117}
# 0.776 +-(0.011) {'criterion': 'entropy', 'max_depth': 20, 'min_samples_leaf': 95, 'min_samples_split': 104}
# 0.776 +-(0.011) {'criterion': 'entropy', 'max_depth': 20, 'min_samples_leaf': 95, 'min_samples_split': 68}
# 0.776 +-(0.007) {'criterion': 'gini', 'max_depth': None, 'min_samples_leaf': 76, 'min_samples_split': 79}
# 0.776 +-(0.007) {'criterion': 'gini', 'max_depth': None, 'min_samples_leaf': 76, 'min_samples_split': 85}
# 0.776 +-(0.007) {'criterion': 'gini', 'max_depth': 15, 'min_samples_leaf': 76, 'min_samples_split': 39}
# 0.776 +-(0.008) {'criterion': 'entropy', 'max_depth': 20, 'min_samples_leaf': 104, 'min_samples_split': 77}
# 0.776 +-(0.011) {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 91, 'min_samples_split': 66}
# 0.776 +-(0.015) {'criterion': 'gini', 'max_depth': 15, 'min_samples_leaf': 38, 'min_samples_split': 64}
# 0.775 +-(0.015) {'criterion': 'gini', 'max_depth': None, 'min_samples_leaf': 37, 'min_samples_split': 79}
# 0.775 +-(0.007) {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 52, 'min_samples_split': 72}
# 0.774 +-(0.008) {'criterion': 'gini', 'max_depth': 20, 'min_samples_leaf': 66, 'min_samples_split': 124}
# 0.774 +-(0.007) {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 51, 'min_samples_split': 62}
# 0.774 +-(0.007) {'criterion': 'gini', 'max_depth': 30, 'min_samples_leaf': 80, 'min_samples_split': 41}
# 0.774 +-(0.016) {'criterion': 'gini', 'max_depth': 20, 'min_samples_leaf': 32, 'min_samples_split': 93}
# 0.774 +-(0.014) {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 88, 'min_samples_split': 111}
# 0.774 +-(0.010) {'criterion': 'gini', 'max_depth': 30, 'min_samples_leaf': 100, 'min_samples_split': 62}
# 0.774 +-(0.015) {'criterion': 'gini', 'max_depth': 15, 'min_samples_leaf': 41, 'min_samples_split': 82}
# 0.773 +-(0.007) {'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 69, 'min_samples_split': 44}
# 0.773 +-(0.005) {'criterion': 'entropy', 'max_depth': 20, 'min_samples_leaf': 61, 'min_samples_split': 82}
# 0.773 +-(0.014) {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 87, 'min_samples_split': 38}
# 0.772 +-(0.010) {'criterion': 'entropy', 'max_depth': 15, 'min_samples_leaf': 49, 'min_samples_split': 78}
# 0.772 +-(0.007) {'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 60, 'min_samples_split': 84}
# 0.771 +-(0.010) {'criterion': 'entropy', 'max_depth': 30, 'min_samples_leaf': 49, 'min_samples_split': 101}
# 0.771 +-(0.003) {'criterion': 'gini', 'max_depth': 30, 'min_samples_leaf': 62, 'min_samples_split': 48}
# 0.771 +-(0.007) {'criterion': 'entropy', 'max_depth': 15, 'min_samples_leaf': 63, 'min_samples_split': 97}
# 0.771 +-(0.011) {'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 53, 'min_samples_split': 85}
# 0.771 +-(0.007) {'criterion': 'entropy', 'max_depth': 15, 'min_samples_leaf': 58, 'min_samples_split': 70}
# 0.771 +-(0.006) {'criterion': 'entropy', 'max_depth': 20, 'min_samples_leaf': 57, 'min_samples_split': 96}
# 0.771 +-(0.010) {'criterion': 'gini', 'max_depth': 30, 'min_samples_leaf': 51, 'min_samples_split': 101}
# 0.771 +-(0.011) {'criterion': 'gini', 'max_depth': 20, 'min_samples_leaf': 47, 'min_samples_split': 59}
# 0.770 +-(0.013) {'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 84, 'min_samples_split': 103}
# 0.770 +-(0.010) {'criterion': 'entropy', 'max_depth': 20, 'min_samples_leaf': 51, 'min_samples_split': 114}
# 0.769 +-(0.014) {'criterion': 'gini', 'max_depth': None, 'min_samples_leaf': 45, 'min_samples_split': 36}

# %%
scores = cross_val_score(busca, x_azar, y_azar, cv=KFold(n_splits=5, shuffle=True))
imprime_score(scores)
# Out:
# Accuracy médio 78.69
# Intervalo [77.64, 79.74]

# %%
melhor = busca.best_estimator_
print(melhor)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=3, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=53, min_samples_split=60,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %% [markdown]
# # Comparando GridSearchCV com RandomizedSearch

# %%
from sklearn.ensemble import RandomForestClassifier
import time

SEED = 301
np.random.seed(SEED)

espaco_de_parametros = {
    "n_estimators" : [10, 100],
    "bootstrap" : [True, False],
    "max_depth" : [3, 5],
    "min_samples_split": [32, 64, 128],
    "min_samples_leaf": [32, 64, 128],
    "criterion": ["gini", "entropy"]
}

tic = time.time()

busca = GridSearchCV(RandomForestClassifier(), espaco_de_parametros, cv=KFold(n_splits=5, shuffle=True))
busca.fit(x_azar, y_azar)

tac = time.time()
print('Tempo %.2f segundos' % (tac - tic))

resultados = pd.DataFrame(busca.cv_results_)
resultados.head()
# Out:
# Tempo 205.64 segundos
#    mean_fit_time  std_fit_time  ...  std_test_score  rank_test_score
# 0       0.036161      0.001707  ...        0.015357              130
# 1       0.329875      0.004960  ...        0.014685               93
# 2       0.035194      0.000675  ...        0.011373               89
# 3       0.329972      0.008453  ...        0.019356              119
# 4       0.034449      0.001313  ...        0.014250              135
#
# [5 rows x 19 columns]

# %%
resultados_ordenados_pela_media = resultados.sort_values('mean_test_score', ascending=False)
for indice, linha in resultados_ordenados_pela_media[:5].iterrows():
  print('%.3f +-(%.3f) %s' % (linha.mean_test_score, linha.std_test_score * 2, linha.params))
# Out:
# 0.780 +-(0.020) {'bootstrap': False, 'criterion': 'gini', 'max_depth': 5, 'min_samples_leaf': 32, 'min_samples_split': 64, 'n_estimators': 10}
# 0.778 +-(0.020) {'bootstrap': True, 'criterion': 'gini', 'max_depth': 5, 'min_samples_leaf': 32, 'min_samples_split': 128, 'n_estimators': 10}
# 0.778 +-(0.030) {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 5, 'min_samples_leaf': 64, 'min_samples_split': 64, 'n_estimators': 10}
# 0.778 +-(0.027) {'bootstrap': False, 'criterion': 'gini', 'max_depth': 5, 'min_samples_leaf': 64, 'min_samples_split': 64, 'n_estimators': 10}
# 0.778 +-(0.033) {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 5, 'min_samples_leaf': 64, 'min_samples_split': 64, 'n_estimators': 100}

# %%
# tic = time.time()
# scores = cross_val_score(busca, x_azar, y_azar, cv=KFold(n_splits=5, shuffle=True))
# tac = time.time()
# print('Tempo %.2f segundos' % tac - tic)
# imprime_score(scores)
# melhor = busca.best_estimator_
# print(melhor)

# %%
SEED = 301
np.random.seed(SEED)

espaco_de_parametros = {
    "n_estimators" : [10, 100],
    "bootstrap" : [True, False],
    "max_depth" : [3, 5],
    "min_samples_split": [32, 64, 128],
    "min_samples_leaf": [32, 64, 128],
    "criterion": ["gini", "entropy"]
}

tic = time.time()

busca = RandomizedSearchCV(RandomForestClassifier(), espaco_de_parametros, cv=KFold(n_splits=5, shuffle=True), n_iter=20)
busca.fit(x_azar, y_azar)

tac = time.time()
print('Tempo %.2f segundos' % (tac - tic))

resultados = pd.DataFrame(busca.cv_results_)
resultados.head()
# Out:
# Tempo 29.82 segundos
#    mean_fit_time  std_fit_time  ...  std_test_score  rank_test_score
# 0       0.416515      0.007521  ...        0.011724               10
# 1       0.056313      0.002539  ...        0.011969               13
# 2       0.567385      0.003539  ...        0.011178                6
# 3       0.034651      0.000947  ...        0.007026               20
# 4       0.057615      0.003290  ...        0.013094               18
#
# [5 rows x 19 columns]

# %%
resultados_ordenados_pela_media = resultados.sort_values('mean_test_score', ascending=False)
for indice, linha in resultados_ordenados_pela_media[:5].iterrows():
  print('%.3f +-(%.3f) %s' % (linha.mean_test_score, linha.std_test_score * 2, linha.params))
# Out:
# 0.776 +-(0.025) {'n_estimators': 100, 'min_samples_split': 32, 'min_samples_leaf': 32, 'max_depth': 5, 'criterion': 'gini', 'bootstrap': False}
# 0.776 +-(0.023) {'n_estimators': 100, 'min_samples_split': 32, 'min_samples_leaf': 128, 'max_depth': 3, 'criterion': 'gini', 'bootstrap': False}
# 0.776 +-(0.024) {'n_estimators': 100, 'min_samples_split': 64, 'min_samples_leaf': 32, 'max_depth': 5, 'criterion': 'entropy', 'bootstrap': True}
# 0.776 +-(0.032) {'n_estimators': 10, 'min_samples_split': 32, 'min_samples_leaf': 64, 'max_depth': 3, 'criterion': 'entropy', 'bootstrap': False}
# 0.775 +-(0.035) {'n_estimators': 10, 'min_samples_split': 32, 'min_samples_leaf': 32, 'max_depth': 5, 'criterion': 'gini', 'bootstrap': True}

# %%
SEED = 301
np.random.seed(SEED)

espaco_de_parametros = {
    "n_estimators" : randint(10, 101),
    "bootstrap" : [True, False],
    "max_depth" : randint(3, 6),
    "min_samples_split": randint(32, 129),
    "min_samples_leaf": randint(32, 129),
    "criterion": ["gini", "entropy"]
}

tic = time.time()

busca = RandomizedSearchCV(RandomForestClassifier(), espaco_de_parametros, cv=KFold(n_splits=5, shuffle=True), n_iter=80)
busca.fit(x_azar, y_azar)

tac = time.time()
print('Tempo %.2f segundos' % (tac - tic))

resultados = pd.DataFrame(busca.cv_results_)
resultados.head()
# Out:
# Tempo 102.09 segundos
#    mean_fit_time  std_fit_time  ...  std_test_score  rank_test_score
# 0       0.344021      0.007986  ...        0.009744               75
# 1       0.262713      0.004509  ...        0.014277               63
# 2       0.248636      0.003039  ...        0.011781               59
# 3       0.164898      0.002556  ...        0.010429               60
# 4       0.253372      0.003754  ...        0.012220               30
#
# [5 rows x 19 columns]

# %%
resultados_ordenados_pela_media = resultados.sort_values('mean_test_score', ascending=False)
for indice, linha in resultados_ordenados_pela_media[:5].iterrows():
  print('%.3f +-(%.3f) %s' % (linha.mean_test_score, linha.std_test_score * 2, linha.params))
# Out:
# 0.779 +-(0.025) {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 5, 'min_samples_leaf': 84, 'min_samples_split': 89, 'n_estimators': 48}
# 0.778 +-(0.031) {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 5, 'min_samples_leaf': 32, 'min_samples_split': 96, 'n_estimators': 18}
# 0.778 +-(0.032) {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 121, 'min_samples_split': 47, 'n_estimators': 27}
# 0.778 +-(0.024) {'bootstrap': False, 'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 96, 'min_samples_split': 98, 'n_estimators': 11}
# 0.777 +-(0.029) {'bootstrap': True, 'criterion': 'gini', 'max_depth': 5, 'min_samples_leaf': 63, 'min_samples_split': 88, 'n_estimators': 69}

# %% [markdown]
# # Se eu não posso ou não consigo usar cross validation

# %%
# 0.6 treino
# 0.2 teste
# 0.2 validacao
from sklearn.model_selection import train_test_split

SEED = 301
np.random.seed(SEED)

x_treino_teste, x_validacao, y_treino_teste, y_validacao = train_test_split(x_azar, y_azar, test_size=0.2, shuffle=True, stratify=y_azar)

# %%
from sklearn.model_selection import StratifiedShuffleSplit

espaco_de_parametros = {
    "n_estimators" : randint(10, 101),
    "bootstrap" : [True, False],
    "max_depth" : randint(3, 6),
    "min_samples_split": randint(32, 129),
    "min_samples_leaf": randint(32, 129),
    "criterion": ["gini", "entropy"]
}

split = StratifiedShuffleSplit(n_splits = 1, test_size = 0.25)

tic = time.time()

busca = RandomizedSearchCV(RandomForestClassifier(), espaco_de_parametros, cv=split, n_iter=5)
busca.fit(x_treino_teste, y_treino_teste)

tac = time.time()
print('Tempo %.2f segundos' % (tac - tic))

resultados = pd.DataFrame(busca.cv_results_)
resultados.head()
# Out:
# Tempo 1.05 segundos
#    mean_fit_time  std_fit_time  ...  std_test_score  rank_test_score
# 0       0.103107           0.0  ...             0.0                3
# 1       0.126701           0.0  ...             0.0                1
# 2       0.077521           0.0  ...             0.0                2
# 3       0.197565           0.0  ...             0.0                5
# 4       0.328255           0.0  ...             0.0                3
#
# [5 rows x 15 columns]

# %%
scores = cross_val_score(busca, x_validacao, y_validacao, cv=split)
scores
# Out:
# array([0.732])
